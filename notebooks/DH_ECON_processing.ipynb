# %% [markdown]
# # Exploring econdata

# %%
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'medium',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'large',
         'ytick.labelsize':'medium'}
pylab.rcParams.update(params)

# %% [markdown]
# ## 1. Load data set from ntuple

# %%
fname = "../data/EGM-Phase2HLTTDRWinter20GSDIGI_NoPU_100evt.root"
ev_dict = uproot.open(fname)["FloatingpointAutoEncoderStrideDummyHistomaxGenmatchGenclustersntuple/HGCalTriggerNtuple"]

# %%
ev_dict['Events'][].keys()
# Out:
# ['EventAuxiliary',
#  'EventProductProvenance',
#  'EventSelections',
#  'BranchListIndexes',
#  'CrossingFramePlaybackInfoNew_mix__DIGI2RAW.',
#  'CrossingFramePlaybackInfoNew_mix__DIGI2RAW./CrossingFramePlaybackInfoNew_mix__DIGI2RAW.present',
#  'CrossingFramePlaybackInfoNew_mix__DIGI2RAW./CrossingFramePlaybackInfoNew_mix__DIGI2RAW.obj',
#  'EBDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.',
#  'EBDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW./EBDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.present',
#  'EBDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW./EBDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.obj',
#  'EBDigiCollection_simEcalUnsuppressedDigis_APD_DIGI2RAW.',
#  'EBDigiCollection_simEcalUnsuppressedDigis_APD_DIGI2RAW./EBDigiCollection_simEcalUnsuppressedDigis_APD_DIGI2RAW.present',
#  'EBDigiCollection_simEcalUnsuppressedDigis_APD_DIGI2RAW./EBDigiCollection_simEcalUnsuppressedDigis_APD_DIGI2RAW.obj',
#  'EEDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.',
#  'EEDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW./EEDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.present',
#  'EEDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW./EEDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.obj',
#  'ESDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.',
#  'ESDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW./ESDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.present',
#  'ESDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW./ESDigiCollection_simEcalUnsuppressedDigis__DIGI2RAW.obj',
#  'FEDRawDataCollection_rawDataCollector__DIGI2RAW.',
#  'FEDRawDataCollection_rawDataCollector__DIGI2RAW./FEDRawDataCollection_rawDataCollector__DIGI2RAW.present',
#  'FEDRawDataCollection_rawDataCollector__DIGI2RAW./FEDRawDataCollection_rawDataCollector__DIGI2RAW.obj',
#  'GenEventInfoProduct_generator__DIGI2RAW.',
#  'GenEventInfoProduct_generator__DIGI2RAW./GenEventInfoProduct_generator__DIGI2RAW.present',
#  'GenEventInfoProduct_generator__DIGI2RAW./GenEventInfoProduct_generator__DIGI2RAW.obj',
#  'QIE10DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HFQIE10DigiCollection_DIGI2RAW.',
#  'QIE10DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HFQIE10DigiCollection_DIGI2RAW./QIE10DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HFQIE10DigiCollection_DIGI2RAW.present',
#  'QIE10DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HFQIE10DigiCollection_DIGI2RAW./QIE10DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HFQIE10DigiCollection_DIGI2RAW.obj',
#  'QIE11DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HBHEQIE11DigiCollection_DIGI2RAW.',
#  'QIE11DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HBHEQIE11DigiCollection_DIGI2RAW./QIE11DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HBHEQIE11DigiCollection_DIGI2RAW.present',
#  'QIE11DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HBHEQIE11DigiCollection_DIGI2RAW./QIE11DataFrameHcalDataFrameContainer_simHcalUnsuppressedDigis_HBHEQIE11DigiCollection_DIGI2RAW.obj',
#  'CSCDetIdCSCComparatorDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCComparatorDigi_DIGI2RAW.',
#  'CSCDetIdCSCComparatorDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCComparatorDigi_DIGI2RAW./CSCDetIdCSCComparatorDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCComparatorDigi_DIGI2RAW.present',
#  'CSCDetIdCSCComparatorDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCComparatorDigi_DIGI2RAW./CSCDetIdCSCComparatorDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCComparatorDigi_DIGI2RAW.obj',
#  'CSCDetIdCSCStripDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCStripDigi_DIGI2RAW.',
#  'CSCDetIdCSCStripDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCStripDigi_DIGI2RAW./CSCDetIdCSCStripDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCStripDigi_DIGI2RAW.present',
#  'CSCDetIdCSCStripDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCStripDigi_DIGI2RAW./CSCDetIdCSCStripDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCStripDigi_DIGI2RAW.obj',
#  'CSCDetIdCSCWireDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCWireDigi_DIGI2RAW.',
#  'CSCDetIdCSCWireDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCWireDigi_DIGI2RAW./CSCDetIdCSCWireDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCWireDigi_DIGI2RAW.present',
#  'CSCDetIdCSCWireDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCWireDigi_DIGI2RAW./CSCDetIdCSCWireDigiMuonDigiCollection_simMuonCSCDigis_MuonCSCWireDigi_DIGI2RAW.obj',
#  'DTLayerIdDTDigiSimLinkMuonDigiCollection_simMuonDTDigis__DIGI2RAW.',
#  'DTLayerIdDTDigiSimLinkMuonDigiCollection_simMuonDTDigis__DIGI2RAW./DTLayerIdDTDigiSimLinkMuonDigiCollection_simMuonDTDigis__DIGI2RAW.present',
#  'DTLayerIdDTDigiSimLinkMuonDigiCollection_simMuonDTDigis__DIGI2RAW./DTLayerIdDTDigiSimLinkMuonDigiCollection_simMuonDTDigis__DIGI2RAW.obj',
#  'RPCDetIdRPCDigiMuonDigiCollection_simMuonRPCDigis__DIGI2RAW.',
#  'RPCDetIdRPCDigiMuonDigiCollection_simMuonRPCDigis__DIGI2RAW./RPCDetIdRPCDigiMuonDigiCollection_simMuonRPCDigis__DIGI2RAW.present',
#  'RPCDetIdRPCDigiMuonDigiCollection_simMuonRPCDigis__DIGI2RAW./RPCDetIdRPCDigiMuonDigiCollection_simMuonRPCDigis__DIGI2RAW.obj',
#  'floatROOTMathCartesian3DROOTMathDefaultCoordinateSystemTagROOTMathPositionVector3D_genParticles_xyz0_DIGI2RAW.',
#  'floatROOTMathCartesian3DROOTMathDefaultCoordinateSystemTagROOTMathPositionVector3D_genParticles_xyz0_DIGI2RAW./floatROOTMathCartesian3DROOTMathDefaultCoordinateSystemTagROOTMathPositionVector3D_genParticles_xyz0_DIGI2RAW.present',
#  'floatROOTMathCartesian3DROOTMathDefaultCoordinateSystemTagROOTMathPositionVector3D_genParticles_xyz0_DIGI2RAW./floatROOTMathCartesian3DROOTMathDefaultCoordinateSystemTagROOTMathPositionVector3D_genParticles_xyz0_DIGI2RAW.obj',
#  'RPCDigiSimLinkedmDetSetVector_simMuonRPCDigis_RPCDigiSimLink_DIGI2RAW.',
#  'RPCDigiSimLinkedmDetSetVector_simMuonRPCDigis_RPCDigiSimLink_DIGI2RAW./RPCDigiSimLinkedmDetSetVector_simMuonRPCDigis_RPCDigiSimLink_DIGI2RAW.present',
#  'RPCDigiSimLinkedmDetSetVector_simMuonRPCDigis_RPCDigiSimLink_DIGI2RAW./RPCDigiSimLinkedmDetSetVector_simMuonRPCDigis_RPCDigiSimLink_DIGI2RAW.obj',
#  'StripDigiSimLinkedmDetSetVector_simMuonGEMDigis_GEM_DIGI2RAW.',
#  'StripDigiSimLinkedmDetSetVector_simMuonGEMDigis_GEM_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonGEMDigis_GEM_DIGI2RAW.present',
#  'StripDigiSimLinkedmDetSetVector_simMuonGEMDigis_GEM_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonGEMDigis_GEM_DIGI2RAW.obj',
#  'StripDigiSimLinkedmDetSetVector_simMuonME0Digis_ME0_DIGI2RAW.',
#  'StripDigiSimLinkedmDetSetVector_simMuonME0Digis_ME0_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonME0Digis_ME0_DIGI2RAW.present',
#  'StripDigiSimLinkedmDetSetVector_simMuonME0Digis_ME0_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonME0Digis_ME0_DIGI2RAW.obj',
#  'StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCStripDigiSimLinks_DIGI2RAW.',
#  'StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCStripDigiSimLinks_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCStripDigiSimLinks_DIGI2RAW.present',
#  'StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCStripDigiSimLinks_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCStripDigiSimLinks_DIGI2RAW.obj',
#  'StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCWireDigiSimLinks_DIGI2RAW.',
#  'StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCWireDigiSimLinks_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCWireDigiSimLinks_DIGI2RAW.present',
#  'StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCWireDigiSimLinks_DIGI2RAW./StripDigiSimLinkedmDetSetVector_simMuonCSCDigis_MuonCSCWireDigiSimLinks_DIGI2RAW.obj',
#  'edmHepMCProduct_generatorSmeared__DIGI2RAW.',
#  'edmHepMCProduct_generatorSmeared__DIGI2RAW./edmHepMCProduct_generatorSmeared__DIGI2RAW.present',
#  'edmHepMCProduct_generatorSmeared__DIGI2RAW./edmHepMCProduct_generatorSmeared__DIGI2RAW.obj',
#  'edmRandomEngineStates_randomEngineStateProducer__DIGI2RAW.',
#  'edmRandomEngineStates_randomEngineStateProducer__DIGI2RAW./edmRandomEngineStates_randomEngineStateProducer__DIGI2RAW.present',
#  'edmRandomEngineStates_randomEngineStateProducer__DIGI2RAW./edmRandomEngineStates_randomEngineStateProducer__DIGI2RAW.obj',
#  'EBSrFlagsSorted_simEcalDigis_ebSrFlags_DIGI2RAW.',
#  'EBSrFlagsSorted_simEcalDigis_ebSrFlags_DIGI2RAW./EBSrFlagsSorted_simEcalDigis_ebSrFlags_DIGI2RAW.present',
#  'EBSrFlagsSorted_simEcalDigis_ebSrFlags_DIGI2RAW./EBSrFlagsSorted_simEcalDigis_ebSrFlags_DIGI2RAW.obj',
#  'EESrFlagsSorted_simEcalDigis_eeSrFlags_DIGI2RAW.',
#  'EESrFlagsSorted_simEcalDigis_eeSrFlags_DIGI2RAW./EESrFlagsSorted_simEcalDigis_eeSrFlags_DIGI2RAW.present',
#  'EESrFlagsSorted_simEcalDigis_eeSrFlags_DIGI2RAW./EESrFlagsSorted_simEcalDigis_eeSrFlags_DIGI2RAW.obj',
#  'EcalTimeDigisSorted_mix_EBTimeDigi_DIGI2RAW.',
#  'EcalTimeDigisSorted_mix_EBTimeDigi_DIGI2RAW./EcalTimeDigisSorted_mix_EBTimeDigi_DIGI2RAW.present',
#  'EcalTimeDigisSorted_mix_EBTimeDigi_DIGI2RAW./EcalTimeDigisSorted_mix_EBTimeDigi_DIGI2RAW.obj',
#  'EcalTimeDigisSorted_mix_EETimeDigi_DIGI2RAW.',
#  'EcalTimeDigisSorted_mix_EETimeDigi_DIGI2RAW./EcalTimeDigisSorted_mix_EETimeDigi_DIGI2RAW.present',
#  'EcalTimeDigisSorted_mix_EETimeDigi_DIGI2RAW./EcalTimeDigisSorted_mix_EETimeDigi_DIGI2RAW.obj',
#  'BTLDetIdBTLSamplemtdhelpersBTLRowColDecodeFTLDataFrameTsSorted_mix_FTLBarrel_DIGI2RAW.',
#  'BTLDetIdBTLSamplemtdhelpersBTLRowColDecodeFTLDataFrameTsSorted_mix_FTLBarrel_DIGI2RAW./BTLDetIdBTLSamplemtdhelpersBTLRowColDecodeFTLDataFrameTsSorted_mix_FTLBarrel_DIGI2RAW.present',
#  'BTLDetIdBTLSamplemtdhelpersBTLRowColDecodeFTLDataFrameTsSorted_mix_FTLBarrel_DIGI2RAW./BTLDetIdBTLSamplemtdhelpersBTLRowColDecodeFTLDataFrameTsSorted_mix_FTLBarrel_DIGI2RAW.obj',
#  'ETLDetIdETLSamplemtdhelpersETLRowColDecodeFTLDataFrameTsSorted_mix_FTLEndcap_DIGI2RAW.',
#  'ETLDetIdETLSamplemtdhelpersETLRowColDecodeFTLDataFrameTsSorted_mix_FTLEndcap_DIGI2RAW./ETLDetIdETLSamplemtdhelpersETLRowColDecodeFTLDataFrameTsSorted_mix_FTLEndcap_DIGI2RAW.present',
#  'ETLDetIdETLSamplemtdhelpersETLRowColDecodeFTLDataFrameTsSorted_mix_FTLEndcap_DIGI2RAW./ETLDetIdETLSamplemtdhelpersETLRowColDecodeFTLDataFrameTsSorted_mix_FTLEndcap_DIGI2RAW.obj',
#  'HBHEDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.',
#  'HBHEDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./HBHEDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.present',
#  'HBHEDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./HBHEDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.obj',
#  'HFDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.',
#  'HFDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./HFDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.present',
#  'HFDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./HFDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.obj',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_EE_DIGI2RAW.',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_EE_DIGI2RAW./DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_EE_DIGI2RAW.present',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_EE_DIGI2RAW./DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_EE_DIGI2RAW.obj',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEback_DIGI2RAW.',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEback_DIGI2RAW./DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEback_DIGI2RAW.present',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEback_DIGI2RAW./DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEback_DIGI2RAW.obj',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEfront_DIGI2RAW.',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEfront_DIGI2RAW./DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEfront_DIGI2RAW.present',
#  'DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEfront_DIGI2RAW./DetIdHGCSampleHGCDataFramesSorted_simHGCalUnsuppressedDigis_HEfront_DIGI2RAW.obj',
#  'HODataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.',
#  'HODataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./HODataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.present',
#  'HODataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./HODataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.obj',
#  'ZDCDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.',
#  'ZDCDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./ZDCDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.present',
#  'ZDCDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW./ZDCDataFramesSorted_simHcalUnsuppressedDigis__DIGI2RAW.obj',
#  'edmTriggerResults_TriggerResults__DIGI2RAW.',
#  'edmTriggerResults_TriggerResults__DIGI2RAW./edmTriggerResults_TriggerResults__DIGI2RAW.present',
#  'edmTriggerResults_TriggerResults__DIGI2RAW./edmTriggerResults_TriggerResults__DIGI2RAW.obj',
#  'float_genParticles_t0_DIGI2RAW.',
#  'float_genParticles_t0_DIGI2RAW./float_genParticles_t0_DIGI2RAW.present',
#  'float_genParticles_t0_DIGI2RAW./float_genParticles_t0_DIGI2RAW.obj',
#  'int_addPileupInfo_bunchSpacing_DIGI2RAW.',
#  'int_addPileupInfo_bunchSpacing_DIGI2RAW./int_addPileupInfo_bunchSpacing_DIGI2RAW.present',
#  'int_addPileupInfo_bunchSpacing_DIGI2RAW./int_addPileupInfo_bunchSpacing_DIGI2RAW.obj',
#  'CaloParticles_mix_MergedCaloTruth_DIGI2RAW.',
#  'CaloParticles_mix_MergedCaloTruth_DIGI2RAW./CaloParticles_mix_MergedCaloTruth_DIGI2RAW.present',
#  'CaloParticles_mix_MergedCaloTruth_DIGI2RAW./CaloParticles_mix_MergedCaloTruth_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_CaloHitsTk_DIGI2RAW.',
#  'PCaloHits_g4SimHits_CaloHitsTk_DIGI2RAW./PCaloHits_g4SimHits_CaloHitsTk_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_CaloHitsTk_DIGI2RAW./PCaloHits_g4SimHits_CaloHitsTk_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_CastorBU_DIGI2RAW.',
#  'PCaloHits_g4SimHits_CastorBU_DIGI2RAW./PCaloHits_g4SimHits_CastorBU_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_CastorBU_DIGI2RAW./PCaloHits_g4SimHits_CastorBU_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_CastorFI_DIGI2RAW.',
#  'PCaloHits_g4SimHits_CastorFI_DIGI2RAW./PCaloHits_g4SimHits_CastorFI_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_CastorFI_DIGI2RAW./PCaloHits_g4SimHits_CastorFI_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_CastorPL_DIGI2RAW.',
#  'PCaloHits_g4SimHits_CastorPL_DIGI2RAW./PCaloHits_g4SimHits_CastorPL_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_CastorPL_DIGI2RAW./PCaloHits_g4SimHits_CastorPL_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_CastorTU_DIGI2RAW.',
#  'PCaloHits_g4SimHits_CastorTU_DIGI2RAW./PCaloHits_g4SimHits_CastorTU_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_CastorTU_DIGI2RAW./PCaloHits_g4SimHits_CastorTU_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_ChamberHits_DIGI2RAW.',
#  'PCaloHits_g4SimHits_ChamberHits_DIGI2RAW./PCaloHits_g4SimHits_ChamberHits_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_ChamberHits_DIGI2RAW./PCaloHits_g4SimHits_ChamberHits_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_EcalHitsEB_DIGI2RAW.',
#  'PCaloHits_g4SimHits_EcalHitsEB_DIGI2RAW./PCaloHits_g4SimHits_EcalHitsEB_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_EcalHitsEB_DIGI2RAW./PCaloHits_g4SimHits_EcalHitsEB_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_EcalHitsEE_DIGI2RAW.',
#  'PCaloHits_g4SimHits_EcalHitsEE_DIGI2RAW./PCaloHits_g4SimHits_EcalHitsEE_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_EcalHitsEE_DIGI2RAW./PCaloHits_g4SimHits_EcalHitsEE_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_EcalHitsES_DIGI2RAW.',
#  'PCaloHits_g4SimHits_EcalHitsES_DIGI2RAW./PCaloHits_g4SimHits_EcalHitsES_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_EcalHitsES_DIGI2RAW./PCaloHits_g4SimHits_EcalHitsES_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_EcalTBH4BeamHits_DIGI2RAW.',
#  'PCaloHits_g4SimHits_EcalTBH4BeamHits_DIGI2RAW./PCaloHits_g4SimHits_EcalTBH4BeamHits_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_EcalTBH4BeamHits_DIGI2RAW./PCaloHits_g4SimHits_EcalTBH4BeamHits_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_FibreHits_DIGI2RAW.',
#  'PCaloHits_g4SimHits_FibreHits_DIGI2RAW./PCaloHits_g4SimHits_FibreHits_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_FibreHits_DIGI2RAW./PCaloHits_g4SimHits_FibreHits_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_HFNoseHits_DIGI2RAW.',
#  'PCaloHits_g4SimHits_HFNoseHits_DIGI2RAW./PCaloHits_g4SimHits_HFNoseHits_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_HFNoseHits_DIGI2RAW./PCaloHits_g4SimHits_HFNoseHits_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_HGCHitsEE_DIGI2RAW.',
#  'PCaloHits_g4SimHits_HGCHitsEE_DIGI2RAW./PCaloHits_g4SimHits_HGCHitsEE_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_HGCHitsEE_DIGI2RAW./PCaloHits_g4SimHits_HGCHitsEE_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_HGCHitsHEback_DIGI2RAW.',
#  'PCaloHits_g4SimHits_HGCHitsHEback_DIGI2RAW./PCaloHits_g4SimHits_HGCHitsHEback_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_HGCHitsHEback_DIGI2RAW./PCaloHits_g4SimHits_HGCHitsHEback_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_HGCHitsHEfront_DIGI2RAW.',
#  'PCaloHits_g4SimHits_HGCHitsHEfront_DIGI2RAW./PCaloHits_g4SimHits_HGCHitsHEfront_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_HGCHitsHEfront_DIGI2RAW./PCaloHits_g4SimHits_HGCHitsHEfront_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_HcalHits_DIGI2RAW.',
#  'PCaloHits_g4SimHits_HcalHits_DIGI2RAW./PCaloHits_g4SimHits_HcalHits_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_HcalHits_DIGI2RAW./PCaloHits_g4SimHits_HcalHits_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_HcalTB06BeamHits_DIGI2RAW.',
#  'PCaloHits_g4SimHits_HcalTB06BeamHits_DIGI2RAW./PCaloHits_g4SimHits_HcalTB06BeamHits_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_HcalTB06BeamHits_DIGI2RAW./PCaloHits_g4SimHits_HcalTB06BeamHits_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_WedgeHits_DIGI2RAW.',
#  'PCaloHits_g4SimHits_WedgeHits_DIGI2RAW./PCaloHits_g4SimHits_WedgeHits_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_WedgeHits_DIGI2RAW./PCaloHits_g4SimHits_WedgeHits_DIGI2RAW.obj',
#  'PCaloHits_g4SimHits_ZDCHITS_DIGI2RAW.',
#  'PCaloHits_g4SimHits_ZDCHITS_DIGI2RAW./PCaloHits_g4SimHits_ZDCHITS_DIGI2RAW.present',
#  'PCaloHits_g4SimHits_ZDCHITS_DIGI2RAW./PCaloHits_g4SimHits_ZDCHITS_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_BCM1FHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_BCM1FHits_DIGI2RAW./PSimHits_g4SimHits_BCM1FHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_BCM1FHits_DIGI2RAW./PSimHits_g4SimHits_BCM1FHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_BHMHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_BHMHits_DIGI2RAW./PSimHits_g4SimHits_BHMHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_BHMHits_DIGI2RAW./PSimHits_g4SimHits_BHMHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_BSCHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_BSCHits_DIGI2RAW./PSimHits_g4SimHits_BSCHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_BSCHits_DIGI2RAW./PSimHits_g4SimHits_BSCHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_CTPPSPixelHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_CTPPSPixelHits_DIGI2RAW./PSimHits_g4SimHits_CTPPSPixelHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_CTPPSPixelHits_DIGI2RAW./PSimHits_g4SimHits_CTPPSPixelHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_CTPPSTimingHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_CTPPSTimingHits_DIGI2RAW./PSimHits_g4SimHits_CTPPSTimingHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_CTPPSTimingHits_DIGI2RAW./PSimHits_g4SimHits_CTPPSTimingHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_FP420SI_DIGI2RAW.',
#  'PSimHits_g4SimHits_FP420SI_DIGI2RAW./PSimHits_g4SimHits_FP420SI_DIGI2RAW.present',
#  'PSimHits_g4SimHits_FP420SI_DIGI2RAW./PSimHits_g4SimHits_FP420SI_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_FastTimerHitsBarrel_DIGI2RAW.',
#  'PSimHits_g4SimHits_FastTimerHitsBarrel_DIGI2RAW./PSimHits_g4SimHits_FastTimerHitsBarrel_DIGI2RAW.present',
#  'PSimHits_g4SimHits_FastTimerHitsBarrel_DIGI2RAW./PSimHits_g4SimHits_FastTimerHitsBarrel_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_FastTimerHitsEndcap_DIGI2RAW.',
#  'PSimHits_g4SimHits_FastTimerHitsEndcap_DIGI2RAW./PSimHits_g4SimHits_FastTimerHitsEndcap_DIGI2RAW.present',
#  'PSimHits_g4SimHits_FastTimerHitsEndcap_DIGI2RAW./PSimHits_g4SimHits_FastTimerHitsEndcap_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_MuonCSCHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_MuonCSCHits_DIGI2RAW./PSimHits_g4SimHits_MuonCSCHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_MuonCSCHits_DIGI2RAW./PSimHits_g4SimHits_MuonCSCHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_MuonDTHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_MuonDTHits_DIGI2RAW./PSimHits_g4SimHits_MuonDTHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_MuonDTHits_DIGI2RAW./PSimHits_g4SimHits_MuonDTHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_MuonGEMHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_MuonGEMHits_DIGI2RAW./PSimHits_g4SimHits_MuonGEMHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_MuonGEMHits_DIGI2RAW./PSimHits_g4SimHits_MuonGEMHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_MuonME0Hits_DIGI2RAW.',
#  'PSimHits_g4SimHits_MuonME0Hits_DIGI2RAW./PSimHits_g4SimHits_MuonME0Hits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_MuonME0Hits_DIGI2RAW./PSimHits_g4SimHits_MuonME0Hits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_MuonRPCHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_MuonRPCHits_DIGI2RAW./PSimHits_g4SimHits_MuonRPCHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_MuonRPCHits_DIGI2RAW./PSimHits_g4SimHits_MuonRPCHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_PLTHits_DIGI2RAW.',
#  'PSimHits_g4SimHits_PLTHits_DIGI2RAW./PSimHits_g4SimHits_PLTHits_DIGI2RAW.present',
#  'PSimHits_g4SimHits_PLTHits_DIGI2RAW./PSimHits_g4SimHits_PLTHits_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TotemHitsRP_DIGI2RAW.',
#  'PSimHits_g4SimHits_TotemHitsRP_DIGI2RAW./PSimHits_g4SimHits_TotemHitsRP_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TotemHitsRP_DIGI2RAW./PSimHits_g4SimHits_TotemHitsRP_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TotemHitsT1_DIGI2RAW.',
#  'PSimHits_g4SimHits_TotemHitsT1_DIGI2RAW./PSimHits_g4SimHits_TotemHitsT1_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TotemHitsT1_DIGI2RAW./PSimHits_g4SimHits_TotemHitsT1_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TotemHitsT2Gem_DIGI2RAW.',
#  'PSimHits_g4SimHits_TotemHitsT2Gem_DIGI2RAW./PSimHits_g4SimHits_TotemHitsT2Gem_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TotemHitsT2Gem_DIGI2RAW./PSimHits_g4SimHits_TotemHitsT2Gem_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsPixelBarrelHighTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsPixelBarrelHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelBarrelHighTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsPixelBarrelHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelBarrelHighTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsPixelBarrelLowTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsPixelBarrelLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelBarrelLowTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsPixelBarrelLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelBarrelLowTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsPixelEndcapHighTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsPixelEndcapHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelEndcapHighTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsPixelEndcapHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelEndcapHighTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsPixelEndcapLowTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsPixelEndcapLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelEndcapLowTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsPixelEndcapLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsPixelEndcapLowTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTECHighTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTECHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTECHighTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTECHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTECHighTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTECLowTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTECLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTECLowTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTECLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTECLowTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTIBHighTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTIBHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIBHighTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTIBHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIBHighTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTIBLowTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTIBLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIBLowTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTIBLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIBLowTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTIDHighTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTIDHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIDHighTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTIDHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIDHighTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTIDLowTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTIDLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIDLowTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTIDLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTIDLowTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTOBHighTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTOBHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTOBHighTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTOBHighTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTOBHighTof_DIGI2RAW.obj',
#  'PSimHits_g4SimHits_TrackerHitsTOBLowTof_DIGI2RAW.',
#  'PSimHits_g4SimHits_TrackerHitsTOBLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTOBLowTof_DIGI2RAW.present',
#  'PSimHits_g4SimHits_TrackerHitsTOBLowTof_DIGI2RAW./PSimHits_g4SimHits_TrackerHitsTOBLowTof_DIGI2RAW.obj',
#  'PileupSummaryInfos_addPileupInfo__DIGI2RAW.',
#  'PileupSummaryInfos_addPileupInfo__DIGI2RAW./PileupSummaryInfos_addPileupInfo__DIGI2RAW.present',
#  'PileupSummaryInfos_addPileupInfo__DIGI2RAW./PileupSummaryInfos_addPileupInfo__DIGI2RAW.obj',
#  'SimClusters_mix_MergedCaloTruth_DIGI2RAW.',
#  'SimClusters_mix_MergedCaloTruth_DIGI2RAW./SimClusters_mix_MergedCaloTruth_DIGI2RAW.present',
#  'SimClusters_mix_MergedCaloTruth_DIGI2RAW./SimClusters_mix_MergedCaloTruth_DIGI2RAW.obj',
#  'SimTracks_g4SimHits__DIGI2RAW.',
#  'SimTracks_g4SimHits__DIGI2RAW./SimTracks_g4SimHits__DIGI2RAW.present',
#  'SimTracks_g4SimHits__DIGI2RAW./SimTracks_g4SimHits__DIGI2RAW.obj',
#  'SimVertexs_g4SimHits__DIGI2RAW.',
#  'SimVertexs_g4SimHits__DIGI2RAW./SimVertexs_g4SimHits__DIGI2RAW.present',
#  'SimVertexs_g4SimHits__DIGI2RAW./SimVertexs_g4SimHits__DIGI2RAW.obj',
#  'TrackingParticles_mix_MergedTrackTruth_DIGI2RAW.',
#  'TrackingParticles_mix_MergedTrackTruth_DIGI2RAW./TrackingParticles_mix_MergedTrackTruth_DIGI2RAW.present',
#  'TrackingParticles_mix_MergedTrackTruth_DIGI2RAW./TrackingParticles_mix_MergedTrackTruth_DIGI2RAW.obj',
#  'TrackingVertexs_mix_InitialVertices_DIGI2RAW.',
#  'TrackingVertexs_mix_InitialVertices_DIGI2RAW./TrackingVertexs_mix_InitialVertices_DIGI2RAW.present',
#  'TrackingVertexs_mix_InitialVertices_DIGI2RAW./TrackingVertexs_mix_InitialVertices_DIGI2RAW.obj',
#  'TrackingVertexs_mix_MergedTrackTruth_DIGI2RAW.',
#  'TrackingVertexs_mix_MergedTrackTruth_DIGI2RAW./TrackingVertexs_mix_MergedTrackTruth_DIGI2RAW.present',
#  'TrackingVertexs_mix_MergedTrackTruth_DIGI2RAW./TrackingVertexs_mix_MergedTrackTruth_DIGI2RAW.obj',
#  'ints_genParticles__DIGI2RAW.',
#  'ints_genParticles__DIGI2RAW./ints_genParticles__DIGI2RAW.present',
#  'ints_genParticles__DIGI2RAW./ints_genParticles__DIGI2RAW.obj',
#  'recoGenJets_ak4GenJets__DIGI2RAW.',
#  'recoGenJets_ak4GenJets__DIGI2RAW./recoGenJets_ak4GenJets__DIGI2RAW.present',
#  'recoGenJets_ak4GenJets__DIGI2RAW./recoGenJets_ak4GenJets__DIGI2RAW.obj',
#  'recoGenJets_ak4GenJetsNoNu__DIGI2RAW.',
#  'recoGenJets_ak4GenJetsNoNu__DIGI2RAW./recoGenJets_ak4GenJetsNoNu__DIGI2RAW.present',
#  'recoGenJets_ak4GenJetsNoNu__DIGI2RAW./recoGenJets_ak4GenJetsNoNu__DIGI2RAW.obj',
#  'recoGenJets_ak8GenJets__DIGI2RAW.',
#  'recoGenJets_ak8GenJets__DIGI2RAW./recoGenJets_ak8GenJets__DIGI2RAW.present',
#  'recoGenJets_ak8GenJets__DIGI2RAW./recoGenJets_ak8GenJets__DIGI2RAW.obj',
#  'recoGenJets_ak8GenJetsNoNu__DIGI2RAW.',
#  'recoGenJets_ak8GenJetsNoNu__DIGI2RAW./recoGenJets_ak8GenJetsNoNu__DIGI2RAW.present',
#  'recoGenJets_ak8GenJetsNoNu__DIGI2RAW./recoGenJets_ak8GenJetsNoNu__DIGI2RAW.obj',
#  'recoGenMETs_genMetCalo__DIGI2RAW.',
#  'recoGenMETs_genMetCalo__DIGI2RAW./recoGenMETs_genMetCalo__DIGI2RAW.present',
#  'recoGenMETs_genMetCalo__DIGI2RAW./recoGenMETs_genMetCalo__DIGI2RAW.obj',
#  'recoGenMETs_genMetTrue__DIGI2RAW.',
#  'recoGenMETs_genMetTrue__DIGI2RAW./recoGenMETs_genMetTrue__DIGI2RAW.present',
#  'recoGenMETs_genMetTrue__DIGI2RAW./recoGenMETs_genMetTrue__DIGI2RAW.obj',
#  'recoGenParticles_genPUProtons__DIGI2RAW.',
#  'recoGenParticles_genPUProtons__DIGI2RAW./recoGenParticles_genPUProtons__DIGI2RAW.present',
#  'recoGenParticles_genPUProtons__DIGI2RAW./recoGenParticles_genPUProtons__DIGI2RAW.obj',
#  'recoGenParticles_genParticles__DIGI2RAW.',
#  'recoGenParticles_genParticles__DIGI2RAW./recoGenParticles_genParticles__DIGI2RAW.present',
#  'recoGenParticles_genParticles__DIGI2RAW./recoGenParticles_genParticles__DIGI2RAW.obj',
#  'int6stdbitsetstdpairs_mix_AffectedAPVList_DIGI2RAW.',
#  'int6stdbitsetstdpairs_mix_AffectedAPVList_DIGI2RAW./int6stdbitsetstdpairs_mix_AffectedAPVList_DIGI2RAW.present',
#  'int6stdbitsetstdpairs_mix_AffectedAPVList_DIGI2RAW./int6stdbitsetstdpairs_mix_AffectedAPVList_DIGI2RAW.obj']

# %%
arrays_toread = [
    "econ_index","econ_data",
    "econ_subdet","econ_zside","econ_layer","econ_waferu","econ_waferv","econ_wafertype",
    "tc_simenergy",
    "tc_subdet","tc_zside","tc_layer","tc_waferu","tc_waferv","tc_wafertype",
    "gen_pt","gen_energy","gen_eta","gen_phi",
    "genpart_pt","genpart_energy","econ_id"
]
events = ev_dict.arrays(arrays_toread)

#Separate the data sets
econ = ak.zip({
    "index": events['econ_index'],
    "id":events['econ_id'],
    "data": events["econ_data"],
    "subdet": events["econ_subdet"],
    "zside": events["econ_zside"],
    "layer": events["econ_layer"],
    "waferu": events["econ_waferu"],
    "waferv": events["econ_waferv"],
})

tc = ak.zip({
    "simenergy": events["tc_simenergy"],
    "subdet": events["tc_subdet"],
    "zside": events["tc_zside"],
    "layer": events["tc_layer"],
    "waferu": events["tc_waferu"],
    "waferv": events["tc_waferv"],
})

gen = ak.zip({
    "pt": events["gen_pt"],
    "energy": events["gen_energy"],
    "eta": events["gen_eta"],
    "phi": events["gen_phi"],
})

# %%
# find wafers that we want to save
# the problem is that the number of wafers from trigger cells: trigger cells/48 
# is not the same as the number of wafers from econ data: econ_data/16
df_tc = ak.to_pandas(tc)
df_econ = ak.to_pandas(econ)
df_gen = ak.to_pandas(gen)

# %%
df_tc
# Out:
#                 simenergy  subdet  zside  layer  waferu  waferv
# entry subentry
# 0     0               0.0       2      1     40      -2      -4
#       1               0.0       2     -1     35      -5       0
#       2               0.0       2      1     35      -6      -5
#       3               0.0       2      1     35      -6      -5
#       4               0.0       2      1     32       7       2
# ...                   ...     ...    ...    ...     ...     ...
# 9     3423            0.0       1     -1      9      -1      -4
#       3424            0.0       1     -1      9      -1      -4
#       3425            0.0       1     -1     13       0      -4
#       3426            0.0       2      1     30      -3       1
#       3427            0.0       1     -1     13      -3      -1
#
# [40065 rows x 6 columns]

# %%
df_simtotal = df_tc.groupby(['entry','subdet','zside','layer','waferu','waferv'])["simenergy"].sum()

#with pd.option_context('display.max_rows', None,
#                       'display.max_columns', None,
#                       'display.precision', 3,
#                       ):
#    print(df_simtotal)
#print(df_simtotal)

# %% [markdown]
# ## 2. Process the econ data set

# %%
df_econ

df_econ.reset_index(inplace=True)
df_econ.set_index(['entry','subdet','zside','layer','waferu','waferv'],inplace=True)

df_econ['simenergy'] = df_simtotal

df_econ.drop(columns='subentry',inplace=True)

# %%
df_econ_wsimenergy = df_econ[df_econ.simenergy > 0]

# %%
df_econ_wsimenergy['layer'] = df_econ_wsimenergy.index.get_level_values('layer')
# Out:
# /uscms_data/d3/dhoang/miniconda3/envs/ERegress/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_econ_wsimenergy
# Out:
#                                         index          id  data  simenergy  \
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4           0  3020456192   320   0.639610
#                                 4           1  3020456192     0   0.639610
#                                 4           2  3020456192     0   0.639610
#                                 4           3  3020456192   320   0.639610
#                                 4           4  3020456192   384   0.639610
# ...                                       ...         ...   ...        ...
# 9     1      1     25    1      3          11  2992922880   128   0.287494
#                                 3          12  2992922880   192   0.287494
#                                 3          13  2992922880   256   0.287494
#                                 3          14  2992922880   256   0.287494
#                                 3          15  2992922880    64   0.287494
#
#                                         layer
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4          30
#                                 4          30
#                                 4          30
#                                 4          30
#                                 4          30
# ...                                       ...
# 9     1      1     25    1      3          25
#                                 3          25
#                                 3          25
#                                 3          25
#                                 3          25
#
# [14576 rows x 5 columns]

# %%
df_econ_wsimenergy[['layer','id']]
# Out:
#                                         layer          id
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4          30  3020456192
#                                 4          30  3020456192
#                                 4          30  3020456192
#                                 4          30  3020456192
#                                 4          30  3020456192
# ...                                       ...         ...
# 9     1      1     25    1      3          25  2992922880
#                                 3          25  2992922880
#                                 3          25  2992922880
#                                 3          25  2992922880
#                                 3          25  2992922880
#
# [14576 rows x 2 columns]

# %%
# Plot index versus layer
plt.scatter(df_econ_wsimenergy[['layer']],df_econ_wsimenergy[['id']])
plt.xlabel('Layer')
plt.ylabel("Wafer ID")
# Out:
# Text(0, 0.5, 'Wafer ID')

# %%
df_econ_wsimenergy[['index','id']]
# Out:
#                                         index          id
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4           0  3020456192
#                                 4           1  3020456192
#                                 4           2  3020456192
#                                 4           3  3020456192
#                                 4           4  3020456192
# ...                                       ...         ...
# 9     1      1     25    1      3          11  2992922880
#                                 3          12  2992922880
#                                 3          13  2992922880
#                                 3          14  2992922880
#                                 3          15  2992922880
#
# [14576 rows x 2 columns]

# %%
from matplotlib.pyplot import figure

df_econ_wsimenergy[['index','id']].groupby(['id']).count().plot(kind='bar', figsize = (20,6))
plt.legend('')
plt.xlabel("Wafer's ID")
plt.ylabel("Events x16")

ax = plt.gca()
ax.axes.xaxis.set_ticklabels([])
# Out:
# [Text(0, 0, ''),
#  Text(1, 0, ''),
#  Text(2, 0, ''),
#  Text(3, 0, ''),
#  Text(4, 0, ''),
#  Text(5, 0, ''),
#  Text(6, 0, ''),
#  Text(7, 0, ''),
#  Text(8, 0, ''),
#  Text(9, 0, ''),
#  Text(10, 0, ''),
#  Text(11, 0, ''),
#  Text(12, 0, ''),
#  Text(13, 0, ''),
#  Text(14, 0, ''),
#  Text(15, 0, ''),
#  Text(16, 0, ''),
#  Text(17, 0, ''),
#  Text(18, 0, ''),
#  Text(19, 0, ''),
#  Text(20, 0, ''),
#  Text(21, 0, ''),
#  Text(22, 0, ''),
#  Text(23, 0, ''),
#  Text(24, 0, ''),
#  Text(25, 0, ''),
#  Text(26, 0, ''),
#  Text(27, 0, ''),
#  Text(28, 0, ''),
#  Text(29, 0, ''),
#  Text(30, 0, ''),
#  Text(31, 0, ''),
#  Text(32, 0, ''),
#  Text(33, 0, ''),
#  Text(34, 0, ''),
#  Text(35, 0, ''),
#  Text(36, 0, ''),
#  Text(37, 0, ''),
#  Text(38, 0, ''),
#  Text(39, 0, ''),
#  Text(40, 0, ''),
#  Text(41, 0, ''),
#  Text(42, 0, ''),
#  Text(43, 0, ''),
#  Text(44, 0, ''),
#  Text(45, 0, ''),
#  Text(46, 0, ''),
#  Text(47, 0, ''),
#  Text(48, 0, ''),
#  Text(49, 0, ''),
#  Text(50, 0, ''),
#  Text(51, 0, ''),
#  Text(52, 0, ''),
#  Text(53, 0, ''),
#  Text(54, 0, ''),
#  Text(55, 0, ''),
#  Text(56, 0, ''),
#  Text(57, 0, ''),
#  Text(58, 0, ''),
#  Text(59, 0, ''),
#  Text(60, 0, ''),
#  Text(61, 0, ''),
#  Text(62, 0, ''),
#  Text(63, 0, ''),
#  Text(64, 0, ''),
#  Text(65, 0, ''),
#  Text(66, 0, ''),
#  Text(67, 0, ''),
#  Text(68, 0, ''),
#  Text(69, 0, ''),
#  Text(70, 0, ''),
#  Text(71, 0, ''),
#  Text(72, 0, ''),
#  Text(73, 0, ''),
#  Text(74, 0, ''),
#  Text(75, 0, ''),
#  Text(76, 0, ''),
#  Text(77, 0, ''),
#  Text(78, 0, ''),
#  Text(79, 0, ''),
#  Text(80, 0, ''),
#  Text(81, 0, ''),
#  Text(82, 0, ''),
#  Text(83, 0, ''),
#  Text(84, 0, ''),
#  Text(85, 0, ''),
#  Text(86, 0, ''),
#  Text(87, 0, ''),
#  Text(88, 0, ''),
#  Text(89, 0, ''),
#  Text(90, 0, ''),
#  Text(91, 0, ''),
#  Text(92, 0, ''),
#  Text(93, 0, ''),
#  Text(94, 0, ''),
#  Text(95, 0, ''),
#  Text(96, 0, ''),
#  Text(97, 0, ''),
#  Text(98, 0, ''),
#  Text(99, 0, ''),
#  Text(100, 0, ''),
#  Text(101, 0, ''),
#  Text(102, 0, ''),
#  Text(103, 0, ''),
#  Text(104, 0, ''),
#  Text(105, 0, ''),
#  Text(106, 0, ''),
#  Text(107, 0, ''),
#  Text(108, 0, ''),
#  Text(109, 0, ''),
#  Text(110, 0, ''),
#  Text(111, 0, ''),
#  Text(112, 0, ''),
#  Text(113, 0, ''),
#  Text(114, 0, ''),
#  Text(115, 0, ''),
#  Text(116, 0, ''),
#  Text(117, 0, ''),
#  Text(118, 0, ''),
#  Text(119, 0, ''),
#  Text(120, 0, ''),
#  Text(121, 0, ''),
#  Text(122, 0, ''),
#  Text(123, 0, ''),
#  Text(124, 0, ''),
#  Text(125, 0, ''),
#  Text(126, 0, ''),
#  Text(127, 0, ''),
#  Text(128, 0, ''),
#  Text(129, 0, ''),
#  Text(130, 0, ''),
#  Text(131, 0, ''),
#  Text(132, 0, ''),
#  Text(133, 0, ''),
#  Text(134, 0, ''),
#  Text(135, 0, ''),
#  Text(136, 0, ''),
#  Text(137, 0, ''),
#  Text(138, 0, ''),
#  Text(139, 0, ''),
#  Text(140, 0, ''),
#  Text(141, 0, ''),
#  Text(142, 0, ''),
#  Text(143, 0, ''),
#  Text(144, 0, ''),
#  Text(145, 0, ''),
#  Text(146, 0, ''),
#  Text(147, 0, ''),
#  Text(148, 0, ''),
#  Text(149, 0, ''),
#  Text(150, 0, ''),
#  Text(151, 0, ''),
#  Text(152, 0, ''),
#  Text(153, 0, ''),
#  Text(154, 0, ''),
#  Text(155, 0, ''),
#  Text(156, 0, ''),
#  Text(157, 0, ''),
#  Text(158, 0, ''),
#  Text(159, 0, ''),
#  Text(160, 0, ''),
#  Text(161, 0, ''),
#  Text(162, 0, ''),
#  Text(163, 0, ''),
#  Text(164, 0, ''),
#  Text(165, 0, ''),
#  Text(166, 0, ''),
#  Text(167, 0, ''),
#  Text(168, 0, ''),
#  Text(169, 0, ''),
#  Text(170, 0, ''),
#  Text(171, 0, ''),
#  Text(172, 0, ''),
#  Text(173, 0, ''),
#  Text(174, 0, ''),
#  Text(175, 0, ''),
#  Text(176, 0, ''),
#  Text(177, 0, ''),
#  Text(178, 0, ''),
#  Text(179, 0, ''),
#  Text(180, 0, ''),
#  Text(181, 0, ''),
#  Text(182, 0, ''),
#  Text(183, 0, ''),
#  Text(184, 0, ''),
#  Text(185, 0, ''),
#  Text(186, 0, ''),
#  Text(187, 0, ''),
#  Text(188, 0, ''),
#  Text(189, 0, ''),
#  Text(190, 0, ''),
#  Text(191, 0, ''),
#  Text(192, 0, ''),
#  Text(193, 0, ''),
#  Text(194, 0, ''),
#  Text(195, 0, ''),
#  Text(196, 0, ''),
#  Text(197, 0, ''),
#  Text(198, 0, ''),
#  Text(199, 0, ''),
#  Text(200, 0, ''),
#  Text(201, 0, ''),
#  Text(202, 0, ''),
#  Text(203, 0, ''),
#  Text(204, 0, ''),
#  Text(205, 0, ''),
#  Text(206, 0, ''),
#  Text(207, 0, ''),
#  Text(208, 0, ''),
#  Text(209, 0, ''),
#  Text(210, 0, ''),
#  Text(211, 0, ''),
#  Text(212, 0, ''),
#  Text(213, 0, ''),
#  Text(214, 0, ''),
#  Text(215, 0, ''),
#  Text(216, 0, ''),
#  Text(217, 0, ''),
#  Text(218, 0, '')]

# %%
df_econ_wsimenergy = df_econ_wsimenergy.rename(columns={"index": "econ_index", "data": "econ_data", "simenergy": "wafer_energy"})

# %%
df_econ_wsimenergy[df_econ_wsimenergy.econ_index == 0]
# Out:
#                                         econ_index  econ_data  wafer_energy
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4                0        704      0.639610
#                    29    0      2                0        384      0.325268
#                    30    2      4                0          0      0.384041
#                    29    0      3                0        256      0.177588
#                          1      2                0        448      0.594947
# ...                                            ...        ...           ...
# 9     1      1     1     1      3                0        384      0.314042
#                    3     2      3                0       1024      0.061016
#                    9     1      4                0        394      0.249215
#                    3     1      2                0        832      0.058836
#                    25    1      3                0        640      0.262666
#
# [911 rows x 3 columns]

# %%
# Econ data: 9 -bit values from each node?
# Wafer energy: in gev

# %%
df_econ_wsimenergy
# Out:
#                                         econ_index  econ_data  wafer_energy
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4                0        704      0.639610
#                                 4                1          0      0.639610
#                                 4                2          0      0.639610
#                                 4                3        704      0.639610
#                                 4                4        768      0.639610
# ...                                            ...        ...           ...
# 9     1      1     25    1      3               11        256      0.262666
#                                 3               12        320      0.262666
#                                 3               13        448      0.262666
#                                 3               14        512      0.262666
#                                 3               15        128      0.262666
#
# [14576 rows x 3 columns]

# %%
df_econ_wsimenergy.reset_index(inplace=True)

# %%
df_econ_wsimenergy.set_index(['entry'],inplace=True)

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(df_econ_wsimenergy.econ_data[(df_econ_wsimenergy.layer==30) & (df_econ_wsimenergy.econ_index==0)])
# Out:
# entry
# 0     704
# 0       0
# 0     192
# 1     768
# 1     576
# 1    1024
# 1     768
# 1     576
# 2     768
# 2     768
# 3     896
# 4    1280
# 4     384
# 4     704
# 4     704
# 5     512
# 5    1024
# 6     448
# 7     640
# 7     320
# 7     832
# 7     448
# Name: econ_data, dtype: uint32

# %%
df_econ_wsimenergy.to_hdf('econ_data_electron_eta2.7_phi1.5_Nov22.h5', key='df', mode='w')

# %%
df_gen.reset_index(inplace=True)

# %%
df_gen.set_index('entry',inplace=True)

# %%
df_gen
# Out:
#                         pt       energy       eta       phi
# entry subentry
# 0     0          80.423019   599.289551  2.697059  1.492554
# 1     0         124.385948   927.308289  2.697515  1.498797
# 2     0          52.817207   391.153015  2.690819  1.491963
# 3     0          33.214794   246.043961  2.691075  1.491199
# 4     0         190.976349  1420.463135  2.695186  1.498270
# 5     0          35.699162   265.670898  2.695733  1.498154
# 6     0         145.696686  1083.321899  2.694855  1.498915
# 7     0         138.498276  1028.103638  2.693192  1.490191
# 8     0          39.580746   294.223419  2.694588  1.497054
# 9     0          25.126141   187.417267  2.698052  1.491331

# %%
df_econ_wsimenergy['gen_energy'] = df_gen['energy']

# %%
df_econ_wsimenergy
