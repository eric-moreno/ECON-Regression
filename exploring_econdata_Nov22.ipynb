# %% [markdown]
# # Exploring econdata

# %%
import uproot
import awkward as ak
import numpy as np
import pandas as pd

# %%
fname = "ntuple.root"
dir = "FloatingpointAutoEncoderStrideDummyHistomaxGenmatchGenclustersntuple/"
ev_dict = uproot.open(fname)["FloatingpointAutoEncoderStrideDummyHistomaxGenmatchGenclustersntuple/HGCalTriggerNtuple"]

# %%
ev_dict.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# run                  | int32_t                  | AsDtype('>i4')
# event                | int32_t                  | AsDtype('>i4')
# lumi                 | int32_t                  | AsDtype('>i4')
# gen_n                | int32_t                  | AsDtype('>i4')
# gen_PUNumInt         | int32_t                  | AsDtype('>i4')
# gen_TrueNumInt       | float                    | AsDtype('>f4')
# vtx_x                | float                    | AsDtype('>f4')
# vtx_y                | float                    | AsDtype('>f4')
# vtx_z                | float                    | AsDtype('>f4')
# gen_eta              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_phi              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_pt               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_energy           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_charge           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# gen_pdgid            | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# gen_status           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# gen_daughters        | std::vector<std::vect... | AsObjects(AsVector(True, As...
# genpart_eta          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_phi          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_pt           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_energy       | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_dvx          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_dvy          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_dvz          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_ovx          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_ovy          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_ovz          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_mother       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_exphi        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_exeta        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_exx          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_exy          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_fbrem        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_pid          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_gen          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_reachedEE    | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_fromBeamPipe | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# genpart_posx         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# genpart_posy         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# genpart_posz         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# econ_n               | int32_t                  | AsDtype('>i4')
# econ_id              | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# econ_subdet          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# econ_zside           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# econ_layer           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# econ_waferu          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# econ_waferv          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# econ_wafertype       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# econ_index           | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# econ_data            | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# ts_n                 | int32_t                  | AsDtype('>i4')
# ts_id                | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# ts_subdet            | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# ts_zside             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# ts_layer             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# ts_wafer             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# ts_wafertype         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# ts_data              | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# ts_pt                | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ts_mipPt             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ts_energy            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ts_eta               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ts_phi               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ts_x                 | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ts_y                 | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ts_z                 | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_n                 | int32_t                  | AsDtype('>i4')
# tc_id                | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# tc_subdet            | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_zside             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_layer             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_waferu            | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_waferv            | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_wafertype         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_cellu             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_cellv             | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# tc_data              | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# tc_uncompressedCh... | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# tc_compressedCharge  | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# tc_pt                | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_mipPt             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_energy            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_simenergy         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_eta               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_phi               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_x                 | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_y                 | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_z                 | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# tc_cluster_id        | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# tc_multicluster_id   | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# tc_multicluster_pt   | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_n               | int32_t                  | AsDtype('>i4')
# cl3d_id              | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# cl3d_pt              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_energy          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_eta             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_phi             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_clusters_n      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cl3d_clusters_id     | std::vector<std::vect... | AsObjects(AsVector(True, As...
# cl3d_layer_pt        | std::vector<std::vect... | AsObjects(AsVector(True, As...
# cl3d_showerlength    | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cl3d_coreshowerle... | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cl3d_firstlayer      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cl3d_maxlayer        | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cl3d_seetot          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_seemax          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_spptot          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_sppmax          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_szz             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_srrtot          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_srrmax          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_srrmean         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_emaxe           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_hoe             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_meanz           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_layer10         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_layer50         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_layer90         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_ntc67           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_ntc90           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_bdteg           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cl3d_quality         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cl3d_ipt             | std::vector<std::vect... | AsObjects(AsVector(True, As...
# cl3d_ienergy         | std::vector<std::vect... | AsObjects(AsVector(True, As...

# %%
arrays_toread = [
    "econ_index","econ_data",
    "econ_subdet","econ_zside","econ_layer","econ_waferu","econ_waferv","econ_wafertype",
    "tc_simenergy",
    "tc_subdet","tc_zside","tc_layer","tc_waferu","tc_waferv","tc_wafertype",
    "gen_pt","gen_energy","gen_eta","gen_phi",
    "genpart_pt","genpart_energy",
]
events = ev_dict.arrays(arrays_toread)

econ = ak.zip({
    "index": events['econ_index'],
    "data": events["econ_data"],
    "subdet": events["econ_subdet"],
    "zside": events["econ_zside"],
    "layer": events["econ_layer"],
    "waferu": events["econ_waferu"],
    "waferv": events["econ_waferv"],
})
tc = ak.zip({
    "simenergy": events["tc_simenergy"],
    "subdet": events["tc_subdet"],
    "zside": events["tc_zside"],
    "layer": events["tc_layer"],
    "waferu": events["tc_waferu"],
    "waferv": events["tc_waferv"],
})
gen = ak.zip({
    "pt": events["gen_pt"],
    "energy": events["gen_energy"],
    "eta": events["gen_eta"],
    "phi": events["gen_phi"],
})

# %%
# find wafers that we want to save
# the problem is that the number of wafers from trigger cells: trigger cells/48 
# is not the same as the number of wafers from econ data: econ_data/16
df_tc = ak.to_pandas(tc)
df_econ = ak.to_pandas(econ)
df_gen = ak.to_pandas(gen)

# %%
df_tc
# Out:
#                 simenergy  subdet  zside  layer  waferu  waferv
# entry subentry
# 0     0               0.0       2      1     40      -2      -4
#       1               0.0       2     -1     35      -5       0
#       2               0.0       2      1     35      -6      -5
#       3               0.0       2      1     32       7       2
#       4               0.0       2      1     31       5       4
# ...                   ...     ...    ...    ...     ...     ...
# 9     2927            0.0       1     -1      9      -1      -4
#       2928            0.0       1     -1      9      -1      -4
#       2929            0.0       1     -1     13       0      -4
#       2930            0.0       2      1     30      -3       1
#       2931            0.0       1     -1     13      -3      -1
#
# [35517 rows x 6 columns]

# %%
df_simtotal = df_tc.groupby(['entry','subdet','zside','layer','waferu','waferv'])["simenergy"].sum()

# %%
#with pd.option_context('display.max_rows', None,
#                       'display.max_columns', None,
#                       'display.precision', 3,
#                       ):
#    print(df_simtotal)
print(df_simtotal)
# Out:
# entry  subdet  zside  layer  waferu  waferv
# 0      1       -1     1      -6      -4        0.0
#                              -5      -1        0.0
#                              -4      -4        0.0
#                                      -3        0.0
#                                      -2        0.0
#                                               ...
# 9      2        1     40      4       2        0.0
#                       41     -3      -5        0.0
#                              -2      -5        0.0
#                       43     -4      -2        0.0
#                               3       4        0.0
# Name: simenergy, Length: 10880, dtype: float32

# %%
df_econ
# Out:
#                 index  data  subdet  zside  layer  waferu  waferv
# entry subentry
# 0     0             0   320       2      1     40      -2      -4
#       1             1     0       2      1     40      -2      -4
#       2             2     0       2      1     40      -2      -4
#       3             3  1088       2      1     40      -2      -4
#       4             4   832       2      1     40      -2      -4
# ...               ...   ...     ...    ...    ...     ...     ...
# 9     17691        11  1024       1     -1     13      -3      -1
#       17692        12   304       1     -1     13      -3      -1
#       17693        13   640       1     -1     13      -3      -1
#       17694        14    48       1     -1     13      -3      -1
#       17695        15   752       1     -1     13      -3      -1
#
# [174080 rows x 7 columns]

# %%
df_econ.index.names
# Out:
# FrozenList(['entry', 'subentry'])

# %%
df_econ.reset_index(inplace=True)

# %%
df_econ.set_index(['entry','subdet','zside','layer','waferu','waferv'],inplace=True)

# %%
df_econ['simenergy'] = df_simtotal

# %%
df_econ.drop(columns='subentry',inplace=True)

# %%
print(df_econ)
# Out:
#                                         index  data  simenergy
# entry subdet zside layer waferu waferv
# 0     2       1    40    -2     -4          0   320        0.0
#                                 -4          1     0        0.0
#                                 -4          2     0        0.0
#                                 -4          3  1088        0.0
#                                 -4          4   832        0.0
# ...                                       ...   ...        ...
# 9     1      -1    13    -3     -1         11  1024        0.0
#                                 -1         12   304        0.0
#                                 -1         13   640        0.0
#                                 -1         14    48        0.0
#                                 -1         15   752        0.0
#
# [174080 rows x 3 columns]

# %%
print(df_econ['simenergy'][df_econ['simenergy'] >0])
# Out:
# entry  subdet  zside  layer  waferu  waferv
# 0      2       1      30     1       4         0.639610
#                                      4         0.639610
#                                      4         0.639610
#                                      4         0.639610
#                                      4         0.639610
#                                                  ...
# 9      1       1      25     1       3         0.262666
#                                      3         0.262666
#                                      3         0.262666
#                                      3         0.262666
#                                      3         0.262666
# Name: simenergy, Length: 14576, dtype: float32

# %%
df_econ_wsimenergy = df_econ[df_econ.simenergy > 0]

# %%
df_econ_wsimenergy = df_econ_wsimenergy.rename(columns={"index": "econ_index", "data": "econ_data", "simenergy": "wafer_energy"})

# %%
df_econ_wsimenergy[df_econ_wsimenergy.econ_index == 0]
# Out:
#                                         econ_index  econ_data  wafer_energy
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4                0        704      0.639610
#                    29    0      2                0        384      0.325268
#                    30    2      4                0          0      0.384041
#                    29    0      3                0        256      0.177588
#                          1      2                0        448      0.594947
# ...                                            ...        ...           ...
# 9     1      1     1     1      3                0        384      0.314042
#                    3     2      3                0       1024      0.061016
#                    9     1      4                0        394      0.249215
#                    3     1      2                0        832      0.058836
#                    25    1      3                0        640      0.262666
#
# [911 rows x 3 columns]

# %%
# Econ data: 9 -bit values from each node?
# Wafer energy: in gev

# %%
df_econ_wsimenergy
# Out:
#                                         econ_index  econ_data  wafer_energy
# entry subdet zside layer waferu waferv
# 0     2      1     30    1      4                0        704      0.639610
#                                 4                1          0      0.639610
#                                 4                2          0      0.639610
#                                 4                3        704      0.639610
#                                 4                4        768      0.639610
# ...                                            ...        ...           ...
# 9     1      1     25    1      3               11        256      0.262666
#                                 3               12        320      0.262666
#                                 3               13        448      0.262666
#                                 3               14        512      0.262666
#                                 3               15        128      0.262666
#
# [14576 rows x 3 columns]

# %%
df_econ_wsimenergy.reset_index(inplace=True)

# %%
df_econ_wsimenergy.set_index(['entry'],inplace=True)

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(df_econ_wsimenergy.econ_data[(df_econ_wsimenergy.layer==30) & (df_econ_wsimenergy.econ_index==0)])
# Out:
# entry
# 0     704
# 0       0
# 0     192
# 1     768
# 1     576
# 1    1024
# 1     768
# 1     576
# 2     768
# 2     768
# 3     896
# 4    1280
# 4     384
# 4     704
# 4     704
# 5     512
# 5    1024
# 6     448
# 7     640
# 7     320
# 7     832
# 7     448
# Name: econ_data, dtype: uint32

# %%
df_econ_wsimenergy.to_hdf('econ_data_electron_eta2.7_phi1.5_Nov22.h5', key='df', mode='w')

# %%
df_gen.reset_index(inplace=True)

# %%
df_gen.set_index('entry',inplace=True)

# %%
df_gen
# Out:
#                         pt       energy       eta       phi
# entry subentry
# 0     0          80.423019   599.289551  2.697059  1.492554
# 1     0         124.385948   927.308289  2.697515  1.498797
# 2     0          52.817207   391.153015  2.690819  1.491963
# 3     0          33.214794   246.043961  2.691075  1.491199
# 4     0         190.976349  1420.463135  2.695186  1.498270
# 5     0          35.699162   265.670898  2.695733  1.498154
# 6     0         145.696686  1083.321899  2.694855  1.498915
# 7     0         138.498276  1028.103638  2.693192  1.490191
# 8     0          39.580746   294.223419  2.694588  1.497054
# 9     0          25.126141   187.417267  2.698052  1.491331

# %%
df_econ_wsimenergy['gen_energy'] = df_gen['energy']

# %%
df_econ_wsimenergy
